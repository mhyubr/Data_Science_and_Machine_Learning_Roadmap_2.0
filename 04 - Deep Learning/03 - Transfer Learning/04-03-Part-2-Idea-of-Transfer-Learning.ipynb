# %%
from luwiji.transfer_learning import illustration

# %% [markdown]
# # Idea: Use pretrained-model for our own case

# %% [markdown]
# ## There are 2 main steps

# %% [markdown]
# ### Step 1: Adaptation

# %% [markdown]
# - Load a pretrained-model
# - freeze the feature extractor
# - modify the classifier to our data, leave it unfreezed
# - train only on the classifier

# %% [markdown]
# ![image.png](attachment:859749f7-0d02-4773-ab8b-a8026efb5f1b.png)

# %% [markdown]
# ### Step 2: Fine-tuning

# %% [markdown]
# - unfreeze some or all the layers
# - retrain using a lower learning rate (let say, 10% of previous learning rate)
# - repeat fine-tuning with lower learning rate if necessary

# %% [markdown]
# ![image.png](attachment:f42400c3-1a30-4494-8cef-56a01b83db32.png)

# %% [markdown]
# # Transfer Learning Common Sense

# %%
illustration.transfer_learning_matrix
